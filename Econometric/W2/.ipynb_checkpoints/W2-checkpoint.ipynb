# %% [markdown]
# # MScFE 610 Econometrics (C22-S1) - Collaborative Review Task M2

# %%
from IPython.display import Image

# %% [markdown]
# ### 1. PartI: Provide a thorough, rigorous analysis of which of the models is preferred. Your analysis should include features of each coefficient, each model, and each of the diagnostic statistics. Do NOT analyze them one-by-one, but by theme as identified in Module 2 of this course
#
# ###    Part II: For the preferred model, give an analysis of the likely correlation among the explanatory variables.

# %%
Image('Models.png')

# %% [markdown]
# ### 2. Use the data file provided: fama_factors_2019.csv

# %% [markdown]
# ### 3. Write the Fama-French 3 factor model equation, specifying what each term means.

# %% [markdown]
# ### 4. Explain in words how the model improves upon CAPM.

# %% [markdown]
# ### 5. Formulate the Fama-French regression using your stock’s returns, all the Fama-French factors, and the benchmark returns.

# %% [markdown]
# ### 6. What is the Greek letter used in front of each factor?

# %% [markdown]
# ### 7. Which model performed better?
